# %%
import pandas as pd

# %%
data = {
    "Behavioral Theory (Бихевиористская теория)": [
        "Noise Trader Models (Модели шумовых трейдеров): Эти модели предполагают, что некоторые участники рынка действуют иррационально. Их торговые действия могут вносить 'шум' в рыночные цены, временно отклоняя их от истинных фундаментальных значений. В этом случае 'умные деньги' могут эксплуатировать эти искажения.",
        "Sentiment-Based Trading (Торговля на основе сентимента): Трейдеры, основываясь на общем настроении рынка или новостях, принимают решения о покупке или продаже активов. Это может привести к значительным колебаниям цен активов.",
        "Event-Driven Strategy (Стратегия, основанная на событиях): D. Miller - Стратегия, при которой трейдеры покупают и продают акции, основываясь на специфических корпоративных событиях. Например, могут инвестировать в компанию, которая объявила о слиянии или поглощении, ожидая роста цены акций",
        "Contrarian Strategy (Контрарианская стратегия): N. Garleanu - Стратегия, при которой инвесторы покупают акции, когда большинство продает, и наоборот. Например, контрарианец может купить акции после большого падения цены, ожидая отскока.",
        "Long Short Equity Strategy (Стратегия 'длинные-короткие' акции): J. B. DeLong et al. - Стратегия, в рамках которой трейдеры одновременно покупают акции, которые, по их мнению, вырастут в цене (длинные позиции), и продают акции, которые, по их мнению, упадут в цене (короткие позиции)."
    ],
    "Efficient Market Hypothesis (Гипотеза эффективного рынка)": [
        "Buy-and-Hold Strategy (Стратегия 'купи и держи'): B. Malkiel - Согласно ГЭР, короткосрочные движения цен непредсказуемы, поэтому попытки 'поймать' их обычно не приносят дополнительной прибыли. Вместо этого инвесторы могут просто купить диверсифицированный портфель акций и держать его на протяжении длительного времени.",
        "Index Fund Investing (Инвестирование в индексные фонды):  John Bogle - Инвесторы стремятся воспроизвести производительность определенного рыночного индекса, полагая, что невозможно систематически превзойти рынок.",
        "High Frequency Trading (Высокочастотная торговля): Michael Monroe Lewis - трейдеры стремятся извлечь прибыль из малых колебаний цен на финансовых рынках, обычно удерживая позиции только в течение очень короткого времени, иногда в течение долей секунды.трейдеры стремятся извлечь прибыль из малых колебаний цен на финансовых рынках, обычно удерживая позиции только в течение очень короткого времени, иногда в течение долей секунды.", "", ""
    ]
}

# %%
df = pd.DataFrame(data)

# %%
df.to_excel('trading_strategies.xlsx', index=False)

# %%
# Out:
#           Behavioral Theory (Бихевиористская теория)
# 0  Noise Trader Models (Модели шумовых трейдеров)...  \
# 1  Sentiment-Based Trading (Торговля на основе се...
# 2  Event-Driven Strategy (Стратегия, основанная н...
# 3  Contrarian Strategy (Контрарианская стратегия)...
# 4  Long Short Equity Strategy (Стратегия 'длинные...
#
#   Efficient Market Hypothesis (Гипотеза эффективного рынка)
# 0  Buy-and-Hold Strategy (Стратегия 'купи и держи...
# 1  Index Fund Investing (Инвестирование в индексн...
# 2  High Frequency Trading (Высокочастотная торгов...
# 3
# 4

# %%
import matplotlib.pyplot as plt

# Data
sectors = ['Энергетические\n ресурсы', 'Финансы', 'Металлургия и\n добыча полезных\n ископаемых',
          'Информационные\n технологии', 'Потребительский сектор', 'Телекоммуникации', 'Другие']
weights = [40.2, 20.7, 18.5, 9.9, 4.0, 2.2, 4.6]

# Plotting
fig, ax = plt.subplots()
ax.pie(weights, labels=sectors, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Отраслевое распределение в IMOEX')

# Display the chart
plt.savefig("imoex_pie_chart.png", dpi=800)

# %%
plt.savefig("imoex_pie_cart.png", dpi=600)
